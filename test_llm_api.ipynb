# %%
import openai
import os
import dotenv

dotenv.load_dotenv()

api_key = os.getenv("OPENAI_API_KEY")

# %%
client = openai.AsyncOpenAI(api_key=api_key)

stream = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "How do I use the OpenAI API in Python?"}
    ],
    stream=True,
)
async for chunk in await stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# To use the OpenAI API in Python, you'll need to follow several steps, from setting up your environment to writing code to make API requests. Below is a step-by-step guide to get you started:
#
# ### 1. Sign Up and Get API Key
# - **Sign Up:** First, you need to create an account at OpenAI's website if you haven't already.
# - **Get API Key:** After logging in, go to the API section of the OpenAI dashboard to obtain your API key.
#
# ### 2. Install Required Libraries
# You'll need Python and the `openai` Python package. If you haven’t already installed it, you can do so via pip:
#
# ```bash
# pip install openai
# ```
#
# ### 3. Set Up Your Environment
# It's a good practice to store your API key in an environment variable for security reasons. On your system, you can do this as follows:
#
# - **On macOS/Linux:** Add the following line to your `~/.bash_profile`, `~/.bashrc`, or `~/.zshrc` file:
#
#   ```bash
#   export OPENAI_API_KEY="your-api-key-here"
#   ```
#
#   Then, run `source ~/.bash_profile` (or the relevant file) to update your environment variables.
#
# - **On Windows:** Use the Command Prompt or PowerShell:
#
#   ```cmd
#   setx OPENAI_API_KEY "your-api-key-here"
#   ```
#
# Make sure to replace `"your-api-key-here"` with your actual API key.
#
# ### 4. Write the Python Code
# Here's an example Python script that uses the OpenAI API to generate text using a GPT model:
#
# ```python
# import os
# import openai
#
# # Ensure the OpenAI API key is set as an environment variable
# openai.api_key = os.getenv("OPENAI_API_KEY")
#
# def generate_text(prompt, model="text-davinci-003", max_tokens=100):
#     try:
#         response = openai.Completion.create(
#             engine=model,
#             prompt=prompt,
#             max_tokens=max_tokens,
#             temperature=0.7
#         )
#         return response.choices[0].text.strip()
#     except Exception as e:
#         return f"Error: {str(e)}"
#
# if __name__ == "__main__":
#     prompt_text = "Once upon a time"
#     generated_text = generate_text(prompt_text)
#     print("Generated Text:\n", generated_text)
# ```
#
# ### 5. Run Your Script
# Save your script and run it in a terminal:
#
# ```bash
# python your_script_name.py
# ```
#
# ### Key Considerations
# - **Model Selection:** Adjust the `model` parameter to the appropriate model you wish to use. For example, you might use `"gpt-3.5-turbo"` for newer versions if available.
# - **API Limits:** Be aware of rate limits and quotas defined in your OpenAI API plan.
# - **Security:** Be careful with how you manage your API key. Avoid hardcoding it in your scripts.
#
# By following these steps, you should be able to interact with the OpenAI API using Python effectively. If you have specific use cases or need further customization, you might also want to refer to the official OpenAI API documentation for more detailed information and advanced features.

# %%
client = openai.OpenAI(api_key=api_key)

stream = client.chat.completions.create(
    model="gpt-4o",
    messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "How do I use the OpenAI API in Python?"}
    ],
    stream=True,
)
for chunk in stream:
    if chunk.choices[0].delta.content is not None:
        print(chunk.choices[0].delta.content, end="")
# Out:
# To use the OpenAI API in Python, you first need to obtain an API key from OpenAI, and then use a library such as the openai Python package, which provides a convenient interface for making requests to the API. Here’s a step-by-step guide:
#
# ### Step 1: Install the OpenAI Python Client
#
# First, ensure you have Python installed on your machine, and then install the OpenAI Python client library. You can do this using pip:
#
# ```bash
# pip install openai
# ```
#
# ### Step 2: Obtain an API Key
#
# 1. Go to the [OpenAI website](https://openai.com/).
# 2. Log in to your account or create one if you don’t have it.
# 3. Navigate to the API section to create or obtain your API key.
#
# ### Step 3: Use the API in Your Python Script
#
# Here is a simple example of how to use the OpenAI API to interact with a model like `gpt-3.5-turbo`:
#
# ```python
# import openai
#
# # Set up your OpenAI API key
# openai.api_key = 'your-api-key-here'
#
# # function to query the model
# def generate_response(prompt):
#     response = openai.Completion.create(
#         model="text-davinci-003",  # Or any other available model
#         prompt=prompt,
#         max_tokens=150,  # Adjust based on your needs
#         temperature=0.7  # Adjust for desired creativity
#     )
#     return response.choices[0].text.strip()
#
# # Use the function
# prompt = "Once upon a time in a land far, far away,"
# response = generate_response(prompt)
# print(response)
# ```
#
# ### Parameters Explained
#
# - **`model`**: Choose the model you're using, such as `text-davinci-003` or `gpt-3.5-turbo`.
# - **`prompt`**: The text prompt you give to the model for generating responses.
# - **`max_tokens`**: The maximum number of tokens to generate in the completion.
# - **`temperature`**: Controls the randomness of the output. A value closer to 0 makes the output more deterministic, while closer to 1 makes it more creative/random.
#
# ### Step 4: Running Your Script
#
# Save your script, and then run it using Python:
#
# ```bash
# python your_script_name.py
# ```
#
# ### Additional Notes
#
# - **Security**: Be sure to keep your API key secure and avoid exposing it in client-side code or version control systems.
# - **Environment Variables**: It's a good practice to store your API key in an environment variable or a secure vault instead of hardcoding it in your script.
# - **API Documentation**: Refer to the [OpenAI API documentation](https://platform.openai.com/docs/api-reference) for more details on available methods, models, and best practices.
#
# ### Leveraging Environment Variables
#
# If you prefer to keep your API key secure using environment variables, you can modify your Python code as follows:
#
# 1. Set your API key in your environment:
#
#    - On Unix/Linux or macOS:
#      ```bash
#      export OPENAI_API_KEY='your-api-key-here'
#      ```
#
#    - On Windows:
#      ```cmd
#      set OPENAI_API_KEY='your-api-key-here'
#      ```
#
# 2. Modify the script to use the environment variable:
#
#    ```python
#    import os
#    import openai
#
#    openai.api_key = os.getenv('OPENAI_API_KEY')
#
#    def generate_response(prompt):
#        response = openai.Completion.create(
#            model="text-davinci-003",
#            prompt=prompt,
#            max_tokens=150,
#            temperature=0.7
#        )
#        return response.choices[0].text.strip()
#
#    prompt = "Once upon a time in a land far, far away,"
#    response = generate_response(prompt)
#    print(response)
#    ```
#
# This approach improves security by keeping sensitive information out of your codebase.

# %%
import google.generativeai as genai
genai.configure(api_key="AIzaSyBPnH1UKrSMh0bcCbTCVbwNAjdq-5Z5arc")

# %%
model = genai.GenerativeModel('gemini-1.5-pro', system_instruction="You are a helpful assistant.")

# %%
response = model.generate_content("How do I use the OpenAI API in Python?", stream=True)
for chunk in response:
    print(chunk.text)
# Out:
# Using
#  the OpenAI API in Python involves these general steps:
#
# 1. **Installation
# :** Install the OpenAI Python library.
#
# 2. **API Key:** Obtain
#  your API key from the OpenAI platform.
#
# 3. **Import and Initialize:** Import the library and set your API key.
#
# 4. **Make API
#  Calls:** Use the library's functions to interact with desired OpenAI services.
#
# 5. **Handle Response:** Process the JSON response returned by the API.
#
#
#
#
# Here's a more detailed breakdown and example using the `openai` library for a completion task:
#
# ```python
# # 1. Installation
# # pip install openai
#
# # 2. API Key (Replace with your
#  actual key)
# import os
# os.environ["OPENAI_API_KEY"] = "YOUR_API_KEY"  # Recommended: Store in environment variables
#
#
# # 3. Import and Initialize (Not needed with environment variables
# )
# import openai
# # openai.api_key = "YOUR_API_KEY" # Alternatively, set directly (less secure)
#
#
#
# # 4. Make API Calls (Example: Text Completion)
# try:
#     response = openai.Completion.create(
#         model="text-
# davinci-003",  # Choose the appropriate model
#         prompt="Write a short story about a robot learning to love:",
#         max_tokens=150,  # Adjust as needed
#         n=1,           # Number of completions to generate
#         stop=None,
# # Optional stop sequence
#         temperature=0.7 # Controls randomness (0.0 more deterministic, 1.0 more random)
#     )
#
#     # 5. Handle Response
#     #  The response is a JSON object.  The generated text is in ['choices'][0]['text']
#
#     generated_text = response.choices[0].text
#     print(generated_text)
#
#
# except openai.OpenAIError as e:
#     print(f"OpenAI API request failed: {e}")
# except Exception as e:
#     print(f"An unexpected error occurred: {
# e}")
#
#
# ```
#
#
# **Explanation and Key Improvements:**
#
# * **API Key Management:** Storing your API key directly in the code is discouraged. Using environment variables is more secure.  The provided example demonstrates this best practice.
# * **Error Handling:** The `try...except` block handles potential `openai.
# OpenAIError` exceptions, providing more robust error management.  This helps in diagnosing issues like incorrect API keys, network problems, or rate limiting.
# * **Model Selection:**  The example uses `text-davinci-003`. You'll need to choose the appropriate model for your task.
# Explore the OpenAI documentation for available models and their strengths.
# * **Parameters:** The `max_tokens`, `n`, `stop`, and `temperature` parameters control aspects of the generation. Adjust them based on your needs. See the API documentation for details on all parameters.
# * **Response Handling:** The
#  code clearly extracts the generated text from the JSON response object.
#
#
#
# **Other OpenAI API Services:**
#
# The OpenAI API offers more than just completions.  You can also use the library for:
#
# * **Chat Completions:**  Use the `openai.ChatCompletion.create()` method.  This
#  is the recommended method for conversational AI.
# * **Edits:**  Modify existing text.
# * **Embeddings:**  Create vector representations of text.
# * **Images:** Generate or edit images.
# * **Fine-tuning:**  Train your own custom models.
#
# Refer to the official OpenAI API documentation
#  for detailed information on all available endpoints, parameters, and usage examples.  The documentation is your best resource for staying up-to-date with the latest features and best practices.
